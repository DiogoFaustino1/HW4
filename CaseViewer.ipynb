# %%
import openmdao.api as om
om.CaseViewer('aerostruct.db')

#Cases -> Select All
#To see how the value of a variable evolves over the iteration history, use Case Index as the X-Axis variable.
#Y-Axis podes ir louco e escolher o que quiseres
# Out:
# VBox(children=(Dropdown(description='Source', layout=Layout(height='auto', width='30%'), options=(), value=Non…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
